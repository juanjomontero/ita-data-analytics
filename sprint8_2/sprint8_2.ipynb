# %% [markdown]
# # SPRINT 8.2 (Juanjo Montero)

# %% [markdown]
# # Importación de las tablas en Microsoft PowerBI
#
# Utilizando como origen de datos un script de Python, se utiliza la función de *pandas* *read_csv* para importar las tablas que habíamos exportado en el sprint 8.1 para cada uno de los dataframes.

# %% [markdown]
# ![Captura de pantalla 2025-06-19 154254.png](attachment:34b446d7-ce50-4ddf-9ba4-5407209048bf.png)

# %% [markdown]
# ![Captura de pantalla 2025-06-19 154428.png](attachment:5ebd0af0-0605-4cbd-9573-7780e1f34445.png)

# %% [markdown]
# ***

# %% [markdown]
# # Visualización en Microsoft PowerBI
#
# Para cada uno de los gráficos realizados en el Sprint 8.1, se realiza su visualización en PowerBI utilizando la opción *Objeto visual de Python*:

# %% [markdown]
# ![image.png](attachment:98821a79-d752-4eb5-81c7-adf6c5bc0511.png)

# %% [markdown]
# Se muestran a continuación las capturas de pantalla para cada uno de los ejercicos así como el código utilizado para la generación de cada una de las visualizaciones:

# %% [markdown]
# ## Nivel 1 - Ejercicio 1
# ### Una variable numérica

# %% [markdown]
# ![image.png](attachment:dbe75d5d-0b8d-4f8c-bff3-fd8277651393.png)

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(user_id, user_age)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:

import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(dataset['user_age'], kde=True, stat='percent', bins=11, color='yellow')
plt.grid(True, linestyle='--', alpha=0.4)

plt.title("Distribución de la edad de los usuarios", fontsize=16)
plt.xlabel("Edad", fontsize=14)
plt.ylabel("% de los usuarios", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(amount)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x=dataset.amount, width = 0.4, color='limegreen')
median = dataset.amount.median()
plt.text(median, 0.25, f'Mediana: {median}', horizontalalignment='center', fontsize=10)

plt.title("Importe de las ventas", fontsize=16)
plt.xlabel("Importe (USD)", fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x=trans_ok.amount, width = 0.4, color='limegreen')

median = trans_ok.amount.median()
plt.text(median, 0.25, f'Mediana: {median}', horizontalalignment='center', fontsize=10)

plt.title("Importe de las ventas", fontsize=16)
plt.xlabel("Importe (USD)", fontsize=14)
plt.show()

# %% [markdown]
# ## Nivel 1 - Ejercicio 2
# ### Dos variables numéricas.

# %% [markdown]
# ![image.png](attachment:6fdabdee-b77d-4feb-981b-230a0a33ca0d.png)

# %%
# Ejecutado en PowerBI comom script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id)
# dataset = dataset.drop_duplicates()

# Pegue o escriba aquí el código de script:
import matplotlib.pyplot as plt
import seaborn as sns

plt.scatter(dataset.amount, dataset.user_age,  color='slategray')

plt.title("Edad del usuario vs. Importe gastado", fontsize=16)
plt.xlabel("Importe (USD)", fontsize=14)
plt.ylabel("Edad", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id)
# dataset = dataset.drop_duplicates()

# Pegue o escriba aquí el código de script:
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(data=dataset, 
             x='transaction_month', 
             y='amount', 
             marker='o', color='blue')

plt.xticks(range(1,13))
plt.grid(True, linestyle='--', alpha=0.4)

plt.title("Evolución del ticket medio a lo largo del año", fontsize=16)
plt.xlabel("Mes de la transacción", fontsize=14)
plt.ylabel("Importe medio (USD)", fontsize=14)
plt.show()

# %% [markdown]
# ## Nivel 1 - Ejercicio 3
# ### Una variable categórica.

# %% [markdown]
# ![image.png](attachment:05808e44-9ed5-4af2-8a8e-07fb2753429d.png)

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id)
# dataset = dataset.drop_duplicates()

# Pegue o escriba aquí el código de script:
import matplotlib.pyplot as plt
import seaborn as sns

dataset.status.value_counts().plot(kind='pie', 
                                     colors=['limegreen','crimson'],
                                     labels= None,
                                     autopct='%1.1f%%')

plt.legend(['Aceptadas','Rechazadas'], title='Estado:', bbox_to_anchor=(0.9,0.9))

plt.title("Estado de las transacciones", fontsize=16, y=0.95)
plt.ylabel(None)
plt.show()

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id, company_country)
# dataset = dataset.drop_duplicates()

# Pegue o escriba aquí el código de script:
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(data=dataset['company_country'],
              order=dataset['company_country'].value_counts().index,
              color='cornflowerblue',
              zorder=3)

plt.grid(True, linestyle='--', alpha=0.4)
plt.xticks(range(0,121,10))

plt.title("Transacciones según país de la empresa", fontsize=16)
plt.xlabel("Número de transacciones", fontsize=14)
plt.ylabel(None)
plt.show()

# %% [markdown]
# ## Nivel 1 - Ejercicio 4
# ### Una variable categórica y una numérica.

# %% [markdown]
# ![image.png](attachment:2a185493-73f3-48e6-b256-8cbca5882a72.png)

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id)
# dataset = dataset.drop_duplicates()

# Pegue o escriba aquí el código de script:
import matplotlib.pyplot as plt
import seaborn as sns

numprods_per_company = dataset.groupby('company_name')['num_prods'].sum()

numprods_top10companies = numprods_per_company.sort_values(ascending=False).head(10)

sns.barplot(data=numprods_top10companies, 
            orient='h',zorder=3, color='orchid')

plt.grid( linestyle='--', alpha=0.7)

plt.title('TOP 10 Empresas', fontsize=16)
plt.xlabel('Unidades vendidas', fontsize=14)
plt.ylabel(None)
plt.tight_layout()
plt.show()

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id)
# dataset = dataset.drop_duplicates()

# Pegue o escriba aquí el código de script:
import matplotlib.pyplot as plt
import seaborn as sns

sales_per_dayoftheweek = dataset.groupby('transaction_weekday')['amount'].sum()

order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sales_per_dayoftheweek = sales_per_dayoftheweek.reindex(order)

sales_per_dayoftheweek.plot(kind='bar', color='limegreen')
plt.xticks(rotation=45)

plt.title('Ventas según día de la semana', fontsize=16)
plt.xlabel(None)
plt.ylabel('Total ventas (USD)', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id, user_country)
# dataset = dataset.drop_duplicates()

# Pegue o escriba aquí el código de script:
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(data=dataset,
            x='user_country',
            y='amount',
            hue='user_country')

plt.title("Importe según país de los usuarios", fontsize=16)
plt.xlabel(None)
plt.ylabel("Importe (USD)", fontsize=14)
plt.show()

# %% [markdown]
# ## Nivel 1 - Ejercicio 5
#
# ### Dos variables categóricas.

# %% [markdown]
# ![image.png](attachment:76252ca2-8d5e-4084-8ab4-8d55a988fde1.png)

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id, user_country)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:

import matplotlib.pyplot as plt
import pandas as pd

crosstab_country_declined = pd.crosstab(dataset['user_country'], dataset['status'])
crosstab_country_declined.plot(kind='bar', stacked=True, color= ['limegreen', 'crimson'])

plt.xticks(rotation=0)
plt.title("Estado de las transacciones según país de los usuarios")
plt.xlabel(None)
plt.ylabel("Número de transacciones")
plt.legend(["Aceptadas", "Rechazadas"])
plt.show()

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:

import matplotlib.pyplot as plt
import pandas as pd

crosstab_month_status = pd.crosstab(dataset.transaction_month, dataset.status)

crosstab_month_status.plot(kind='bar', stacked=True, color= ['limegreen', 'crimson'])

plt.xticks(rotation=0)
plt.title("Estado de las transacciones desglosado por meses", fontsize=16)
plt.xlabel(None)
plt.ylabel("número de transacciones", fontsize=14)
plt.legend(["Aceptadas", "Rechazadas"])
plt.show()

# %% [markdown]
# ## Nivel 1 - Ejercicio 6
#
# ### Tres variables.

# %% [markdown]
# ![image.png](attachment:f37296f5-1632-432e-ad91-3c02969b221d.png)

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:

import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(data=dataset,
            x='transaction_month',
            y='amount',
            hue='user_country',
            errorbar=None,
            marker='o')

plt.grid( linestyle='--', alpha=0.4)

plt.title("Ticket medio mensual por país de los usuarios", fontsize=16)
plt.xlabel(None)
plt.ylabel("Importe medio (USD)", fontsize=14)
plt.xticks(ticks=range(1,13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title=None)
plt.show()

# %% [markdown]
# ## Nivel 1- Ejercicio 7
# ### Graficar un Pairplot.

# %% [markdown]
# ![image.png](attachment:f75adfc2-ea36-43be-b403-0965bfc52b5c.png)

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id, amount, num_prods, transaction_month, user_age, status)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:

import matplotlib.pyplot as plt
import seaborn as sns

variables_to_pairplot = ['amount', 'num_prods', 'transaction_month', 'user_age', 'status']
sns.pairplot(dataset[variables_to_pairplot], hue='status', palette=['limegreen','crimson'])
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Nivel 2 - Exercicio 1 y 2
# ### Correlación de las variables numéricas e implemetación de un jointplot

# %% [markdown]
# ![image.png](attachment:75b3196e-1dce-4cd8-94b4-d285b618b9c1.png)

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id, amount, num_prods, transaction_month, user_age)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:

import matplotlib.pyplot as plt
import seaborn as sns

numeric_variables = dataset[['amount', 'num_prods', 'transaction_month', 'user_age']]

sns.heatmap(numeric_variables.corr(), 
            annot=True, 
            vmin=-1, vmax=1,
            cmap='RdBu')

plt.title("Correlación de las variables numéricas", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id, user_age, amount, status)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:

import matplotlib.pyplot as plt
import seaborn as sns

g = sns.jointplot(x = dataset.user_age,
                  y = dataset.amount,
                  hue = dataset.status,
                  palette = ['limegreen', 'crimson'])

g.set_axis_labels("Edad de los usuarios", "Importe (USD", fontsize=14)

plt.suptitle("Importe vs. Edad \n(segregado por estado de la transacción)", fontsize=16)
plt.legend(title='Estado transacción')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

g = sns.jointplot(x = trans_all.user_age,
                  y = trans_all.amount,
                  hue = trans_all.status,
                  palette = ['limegreen', 'crimson'])

g.set_axis_labels("Edad de los usuarios", "Importe (USD", fontsize=14)

plt.suptitle("Importe vs. Edad (segregado por estado de la transacción)", fontsize=16)
plt.legend(title='Estado transacción')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Nivel 3 - Ejercicio 1
# ### Implementación de un violinplot con otro tipo de gráfico

# %% [markdown]
# ![image.png](attachment:9206c201-595a-432f-a5a2-9ca2d6d208ef.png)

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id, num_prods, amount)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:

import matplotlib.pyplot as plt
import seaborn as sns

sns.violinplot(data=dataset,
               x='num_prods', 
               y='amount', 
               hue='num_prods', 
               palette='Blues')


sns.swarmplot(data=dataset,
              x='num_prods', 
              y='amount', 
              hue='status', 
              size=4, linewidth=1, palette=['limegreen', 'crimson'])

plt.legend(title='Número productos', bbox_to_anchor=(1,1))
plt.title('Distribución según el número de productos en el pedido', fontsize=16)
plt.xlabel('Transacciones')
plt.ylabel('Cantidad productos por transacción')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Nivel 3 - Ejercicio 2
# ### Generar un FacetGrid para visualizar múltiples aspectos de les datos simultáneamente.

# %% [markdown]
# ![image.png](attachment:cdbe4157-1363-44a2-b3ac-e0ba07429a8e.png)

# %%
# Ejecutado en PowerBI como script de Python:

# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 
# dataset = pandas.DataFrame(transaction_id, user_country, transaction_year, amount, status)
# dataset = dataset.drop_duplicates()
# Pegue o escriba aquí el código de script:

import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(dataset, 
                  col='user_country', 
                  row='transaction_year', 
                  hue='status', palette=['limegreen', 'crimson'], 
                  margin_titles=True)

g.map(sns.histplot, 'amount', bins=15)
g.add_legend(title='Transaction status',  loc='upper right', bbox_to_anchor=(1, 0.3))
#bbox_to_anchor=(1, 0.5),

g.fig.suptitle('Transaction amount by year and user\'s country', fontsize=16, y=1.05)
g.set_titles(col_template='Usuarios de {col_name}', row_template='AÑO {row_name}')
g.set_axis_labels('Distribución IMPORTE (USD)', 'Número de transacciones')

plt.show()
